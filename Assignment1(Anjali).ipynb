# %%
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the dataset
df = pd.read_csv("Anjali Chaudhary - day - day.csv")

# %%
# Drop unnecessary columns
df.drop(['instant', 'dteday', 'casual', 'registered'],axis=1,inplace=True)

# %%
# Handle categorical variables using one-hot encoding
categorical_vars = ['season','yr','mnth','holiday','weekday','workingday', 'weathersit']
df = pd.get_dummies(df, columns=categorical_vars, drop_first=True)

# %%
# Split into training and testing sets
X = df.drop('cnt', axis=1)
y = df['cnt']

# %%
X=X.astype(float)
y=y.astype(float)

# %%
# Build regression model
X_sm = sm.add_constant(X)

# %%
model = sm.OLS(y, X_sm).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     134.2
# Date:                Fri, 17 Oct 2025   Prob (F-statistic):          1.84e-263
# Time:                        17:39:15   Log-Likelihood:                -5873.8
# No. Observations:                 730   AIC:                         1.181e+04
# Df Residuals:                     700   BIC:                         1.195e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1926.0315    237.566      8.107      0.000    1459.604    2392.459
# temp            68.0898     34.265      1.987      0.047       0.815     135.365
# atemp           35.6324     29.319      1.215      0.225     -21.930      93.195
# hum            -15.0604      2.937     -5.127      0.000     -20.827      -9.293
# windspeed      -41.2795      6.214     -6.643      0.000     -53.480     -29.079
# season_2       878.6331    180.085      4.879      0.000     525.061    1232.205
# season_3       829.2539    213.780      3.879      0.000     409.526    1248.982
# season_4      1570.7965    181.742      8.643      0.000    1213.972    1927.621
# yr_1          2021.5654     58.565     34.518      0.000    1906.582    2136.549
# mnth_2         166.1521    144.861      1.147      0.252    -118.262     450.566
# mnth_3         556.7314    166.078      3.352      0.001     230.661     882.802
# mnth_4         484.1716    248.861      1.946      0.052      -4.432     972.775
# mnth_5         763.3659    268.883      2.839      0.005     235.453    1291.279
# mnth_6         557.0804    284.042      1.961      0.050      -0.595    1114.756
# mnth_7          77.3659    315.774      0.245      0.807    -542.612     697.344
# mnth_8         483.3280    304.832      1.586      0.113    -115.166    1081.822
# mnth_9        1030.6412    266.486      3.868      0.000     507.434    1553.848
# mnth_10        546.0498    242.429      2.252      0.025      70.074    1022.026
# mnth_11        -90.4100    231.693     -0.390      0.696    -545.306     364.485
# mnth_12        -76.3623    182.895     -0.418      0.676    -435.451     282.726
# holiday_1     -927.6662    456.492     -2.032      0.043   -1823.923     -31.409
# weekday_1       81.3292    498.616      0.163      0.870    -897.633    1060.291
# weekday_2       52.6687    495.350      0.106      0.915    -919.881    1025.218
# weekday_3      185.4148    491.571      0.377      0.706    -779.715    1150.544
# weekday_4      339.2259    498.476      0.681      0.496    -639.461    1317.912
# weekday_5      329.1052    498.429      0.660      0.509    -649.489    1307.700
# weekday_6      -52.1912    107.502     -0.485      0.627    -263.256     158.873
# workingday_1  -398.0923    495.572     -0.803      0.422   -1371.079     574.894
# weathersit_2  -458.7489     77.470     -5.922      0.000    -610.850    -306.647
# weathersit_3 -1955.0504    197.496     -9.899      0.000   -2342.805   -1567.296
# ==============================================================================
# Omnibus:                      121.795   Durbin-Watson:                   1.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.051
# Skew:                          -0.853   Prob(JB):                     1.17e-70
# Kurtosis:                       5.770   Cond. No.                     3.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Temperature vs Demand
sns.scatterplot(x=df["temp"], y=df["cnt"])
plt.title("Temperature vs Bike Demand")
plt.xlabel("Temperature")
plt.ylabel("Bike Demand")
plt.show()

# %%
# Humidity vs Demand
sns.scatterplot(x=df["hum"], y=df["cnt"])
plt.title("Humidity vs Bike Demand")
plt.xlabel("Humidity")
plt.ylabel("Bike Demand")
plt.show()

# %%
# Windspeed vs Demand
sns.scatterplot(x=df["windspeed"], y=df["cnt"])
plt.title("Windspeed vs Bike Demand")
plt.xlabel("Windspeed")
plt.ylabel("Bike Demand")
plt.show()
